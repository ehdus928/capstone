# %%
import psycopg2
import pandas as pd
import numpy as np

conn_string = ""
conn = psycopg2.connect(conn_string)
cur=conn.cursor()

cur.execute("SELECT * FROM capstone.cap_data;")
result = cur.fetchall()

# %%
columns = ["row_id","subject_id","hadm_id","intime","outtime","information",'readmission']
df = pd.DataFrame(result,columns = columns)
df.head(10)
# Out:
#    row_id  subject_id  hadm_id              intime             outtime  \
# 0   23620       19323   111122 2115-02-04 07:50:48 2115-02-05 07:01:56
# 1   17936       14657   111125 2200-07-05 19:38:11 2200-07-06 23:03:12
# 2   17038       13906   111126 2101-09-01 18:30:04 2101-09-03 18:00:12
# 3   26850       21986   111130 2116-02-25 19:32:29 2116-02-27 18:21:27
# 4    5495        4550   111133 2127-07-12 11:15:51 2127-07-14 16:50:50
# 5   56240       91491   111134 2124-01-28 17:29:03 2124-01-29 13:02:51
# 6   13836       11314   111136 2176-07-23 12:04:22 2176-07-24 15:48:12
# 7   24562       20122   111138 2140-10-23 22:46:51 2140-10-26 17:34:39
# 8   34437       28183   111139 2166-03-30 09:16:43 2166-03-31 13:52:10
# 9   29259       23942   111141 2189-10-01 11:36:20 2189-10-03 22:07:53
#
#                                          information  readmission
# 0  [**2115-2-4**] 5:38 AM\n CHEST (PORTABLE AP)  ...            0
# 1  [**2200-7-6**] 11:53 AM\n MR L SPINE SCAN     ...            0
# 2  [**2101-9-3**] 9:51 AM\n RENAL U.S.           ...            0
# 3  [**2116-2-25**] 8:15 PM\n CHEST (PRE-OP PA & L...            0
# 4  [**2127-7-12**] 1:00 PM\n CHEST (PORTABLE AP) ...            0
# 5  Subdural hemorrhage (SDH) s/p crani & evacuati...            0
# 6  [**2176-7-22**] 2:43 PM\n CAROTID SERIES COMPL...            0
# 7  [**2140-10-25**] 6:31 AM\n CHEST (PORTABLE AP)...            0
# 8  CCU NPN\nS: " I want to go home."\nO: See vs/o...            0
# 9  [**2189-10-1**] 3:33 PM\n CHEST (PORTABLE AP) ...            0

# %%
import re

def preprocess(x):
    y=re.sub('\\[(.*?)\\]','',x) #remove de-identified brackets
    y=re.sub('[0-9]+\.','',y) #remove 1.2. since the segmenter segments based on this
    y=re.sub('dr\.','doctor',y)
    y=re.sub('m\.d\.','md',y)
    y=re.sub('admission date:','',y)
    y=re.sub('discharge date:','',y)
    y=re.sub('--|__|==','',y)
    # remove, digits, spaces
    result = " ".join(y.split())
    
    return result

# %%
total_lst = []
for info in df.iloc[:45942]['information']:
    info = info.split('\n')
    part_lst = []
    for sen in info:
        tmp=preprocess(sen)
        part_lst.append(tmp)
    total_lst.append(part_lst)
    
print(total_lst)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
total = np.array(total_lst)
data = pd.DataFrame(total,columns=["Text"])
print(f'df\'s shape:{df.shape}, data\'s shape:{data.shape}')
new_df = pd.concat([df,data],axis=1)
print(f'new_df\'s shape: {new_df.shape}')
new_df.head()
# Out:
# df's shape:(45942, 7), data's shape:(45942, 1)
# new_df's shape: (45942, 8)
# C:\Users\170890\Anaconda3\envs\nlp2\lib\site-packages\ipykernel_launcher.py:1: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   
#
#                                                inform
# 0   5:38 AM. CHEST (PORTABLE AP) Clip #. Reason: r...
# 1   11:53 AM. MR L SPINE SCAN Clip #. Reason: with...
# 2   9:51 AM. RENAL U.S. Clip #. Reason: HX RENAL I...
# 3   8:15 PM. CHEST (PRE-OP PA & LAT) Clip #. Reaso...
# 4   1:00 PM. CHEST (PORTABLE AP) Clip #. Reason: c...
# 5   Subdural hemorrhage (SDH) s/p crani & evacuati...
# 6   2:43 PM. CAROTID SERIES COMPLETE Clip #. Reaso...
# 7   6:31 AM. CHEST (PORTABLE AP) Clip #. Reason: p...
# 8   CCU NPN. S: " I want to go home.". O: See vs/o...
# 9   3:33 PM. CHEST (PORTABLE AP) Clip #. Reason: P...
# 10  PATIENT/TEST INFORMATION:. Indication: Chest p...
# 11  Chief Complaint: Cholangitis. 24 Hour Events:....
# 12  6:29 AM. CHEST (PORTABLE AP) Clip #. Reason: e...
# 13  7:16 AM. CT HEAD W/O CONTRAST Clip #. Reason: ...
# 14  8:12 PM. CHEST (PORTABLE AP) Clip #. Reason: p...
# 15  Hyponatremia (low sodium, hyposmolality). Asse...
# 16  10:06 PM. CT ABDOMEN W/CONTRAST; CT PELVIS W/C...
# 17  5:06 PM. CT CHEST W/CONTRAST; CT ABD W&W/O C C...
# 18  2:14 PM. CHEST (PORTABLE AP); -76 BY SAME PHYS...
# 19  2:14 PM. CHEST (PORTABLE AP); -76 BY SAME PHYS...

# %%
f_df.drop(['row_id', 'subject_id','hadm_id','intime', 'outtime', 'information', 'Text'], axis=1, inplace=True)
f_df.head(20)
# Out:
#     readmission                                             inform
# 0             0  5:38 AM. CHEST (PORTABLE AP) Clip #. Reason: r...
# 1             0  11:53 AM. MR L SPINE SCAN Clip #. Reason: with...
# 2             0  9:51 AM. RENAL U.S. Clip #. Reason: HX RENAL I...
# 3             0  8:15 PM. CHEST (PRE-OP PA & LAT) Clip #. Reaso...
# 4             0  1:00 PM. CHEST (PORTABLE AP) Clip #. Reason: c...
# 5             0  Subdural hemorrhage (SDH) s/p crani & evacuati...
# 6             0  2:43 PM. CAROTID SERIES COMPLETE Clip #. Reaso...
# 7             0  6:31 AM. CHEST (PORTABLE AP) Clip #. Reason: p...
# 8             0  CCU NPN. S: " I want to go home.". O: See vs/o...
# 9             0  3:33 PM. CHEST (PORTABLE AP) Clip #. Reason: P...
# 10            0  PATIENT/TEST INFORMATION:. Indication: Chest p...
# 11            0  Chief Complaint: Cholangitis. 24 Hour Events:....
# 12            0  6:29 AM. CHEST (PORTABLE AP) Clip #. Reason: e...
# 13            0  7:16 AM. CT HEAD W/O CONTRAST Clip #. Reason: ...
# 14            0  8:12 PM. CHEST (PORTABLE AP) Clip #. Reason: p...
# 15            0  Hyponatremia (low sodium, hyposmolality). Asse...
# 16            0  10:06 PM. CT ABDOMEN W/CONTRAST; CT PELVIS W/C...
# 17            0  5:06 PM. CT CHEST W/CONTRAST; CT ABD W&W/O C C...
# 18            0  2:14 PM. CHEST (PORTABLE AP); -76 BY SAME PHYS...
# 19            1  2:14 PM. CHEST (PORTABLE AP); -76 BY SAME PHYS...

# %%
print(len(dataset), dataset.features)
